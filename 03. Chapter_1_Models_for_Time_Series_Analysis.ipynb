# %% [markdown]
# # Models for time series analysis
#
# The purpose of time series analysis is to develop a mathematical model that can explain the observed behavior of a time series and possibly forecast the future state of the series. The chosen model should be able to account for one or more of the internal structures. To this end, we will give an overview of the following general models that are often used as building blocks of time series analysis:
#
#     * Zero mean models
#     * Random walk
#     * Trend models
#     * Seasonality models
#
#
# # Zero mean models
#
# The zero-mean models have a constant mean and constant variance and shows no predictable trends or seasonality. Observations from a zero mean model are assumed to be <b> independent and identically distributed (iid) </b> and represent the random noise around a fixed mean, which has been deducted from the time series as a constant term.

# %%
import os
import numpy as np
# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# os.chdir('D:/Practical Time Series/')

# %%
zero_mean_series = np.random.normal(loc=0.0, scale=1., size=100)

# %%
plt.figure(figsize=(5.5, 5.5))
g = sns.tsplot(zero_mean_series)
g.set_title('Zero mean model')
g.set_xlabel('Time index')
plt.savefig('plots/B07887_01_12.png', format='png', dpi=300)
# Out:
# /home/sara/anaconda3/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# The zero mean with constant variance represents a random noise that can assume infinitely possible real values and is suited for representing irregular variations in the time series of a continuous variable.
#
# # Random walk
#
# A random walk is given as a sum of n iids, which has zero mean and constant variance. Based on this definition, the realization of a random walk at time index t is given by the sum S = x1 + x2 + ... + xn. The following figure shows the random walk obtained from iids, which vary according to a normal distribution of zero mean and unit variance.
#
# The random walk is important because if such behavior is found in a time series, it can be easily reduced to zero mean model by taking differences of the observations from two consecutive time indices as St - St-1 = xt is an iid with zero mean and constant variance.

# %%
random_walk = np.cumsum(zero_mean_series)

# %%
plt.figure(figsize=(5.5, 5.5))
g = sns.tsplot(random_walk)
g.set_title('Random Walk')
g.set_xlabel('Time index')
plt.savefig('plots/B07887_01_13.png', format='png', dpi=300)
# Out:
# /home/sara/anaconda3/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Trend models
#
# This type of model aims to capture the long run trend in the time series that can be fitted as linear regression of the time index.
#
# # Seasonality models
#
# Seasonality manifests as periodic and repetitive fluctuations in a time series and hence are modeled as sum of weighted sum of sine waves of known periodicity.
# <br><br>
# The four models described here are building blocks of a fully-fledged time series model. As you might have gathered by now, a zero sum model represents irreducible error of the system and all of other three models aim to transform a given time series to the zero sum models through suitable mathematical transformations. To get forecasts in terms of the original time series, relevant inverse transformations are applied.
